# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
EMOTIONS = ['angry','disgust','fear','happy','sad','surprise','neutral']
IMG_SIZE = (64, 64)
BASE_DIR = os.path.abspath(os.path.join(os.getcwd(), os.pardir))

# — FER-2013_sampled is right under the project root
SAMPLE_DIR = os.path.join(BASE_DIR, "FER-2013_sampled")
TRAIN_DIR = os.path.join(SAMPLE_DIR, r'C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000')
# Check class distribution 
class_counts = {}
for emotion in EMOTIONS: 
    path = os.path.join(TRAIN_DIR, emotion)
    count = len(os.listdir(path))
    class_counts[emotion] = count

# %%
# Plot class distribution 
plt.figure(figsize=(8, 5))
plt.bar(class_counts.keys(), class_counts.values(), color='skyblue')
plt.title("Class Distribution in Training Set")
plt.xlabel("Emotion") 
plt.ylabel("Number of Images")
plt.xticks(rotation=45)
plt.show()

# %%
# Visualize sample images
fig, axes = plt.subplots(1, len(EMOTIONS), figsize=(15, 3))
for idx, emotion in enumerate(EMOTIONS):
    emo_path = os.path.join(TRAIN_DIR, emotion)
    img_name = os.listdir(emo_path)[0]
    img = Image.open(os.path.join(emo_path, img_name)).convert("L")
    axes[idx].imshow(img, cmap='gray')
    axes[idx].set_title(emotion)
    axes[idx].axis("off")
plt.suptitle("Sample Images from Each Class")
plt.tight_layout()
plt.show()

# %%
# Analyze image properties (on a small sample)
img_shapes = []
intensities = []

for emotion in EMOTIONS:
    folder = os.path.join(TRAIN_DIR, emotion)
    for img_name in os.listdir(folder)[:20]:  # Limit to 20 for speed
        img = Image.open(os.path.join(folder, img_name)).convert("L")
        arr = np.array(img)
        img_shapes.append(arr.shape)
        intensities.append(arr.ravel()) # Flatten to 1D for intensity analysis

# %%
# Check average shape (expecting uniform if already cleaned)
unique_shapes = set(img_shapes)
print("Unique image shapes:", unique_shapes)

# Plot intensity distribution
flat_pixels = np.concatenate(intensities)
plt.hist(flat_pixels, bins=50, color='gray')
plt.title("Pixel Intensity Distribution (Sampled Images)")
plt.xlabel("Pixel Value")
plt.ylabel("Frequency")
plt.show()
# Out:
# Unique image shapes: {(48, 48)}

# %%
#Check for duplicates or Corrupt Images 
def check_duplicates_and_corrupt_images(directory):
    seen = set()
    duplicates = []
    corrupt_images = []

    for emotion in EMOTIONS:
        path = os.path.join(directory, emotion)
        for img_name in os.listdir(path):
            img_path = os.path.join(path, img_name)
            try:
                img = Image.open(img_path)
                img.verify()  # Check if image is corrupt
                img_hash = hash(img.tobytes())
                if img_hash in seen:
                    duplicates.append(img_path)
                else:
                    seen.add(img_hash)
            except (IOError, SyntaxError) as e:
                corrupt_images.append(img_path)

    return duplicates, corrupt_images

# %%
import hashlib

hashes = set()
duplicates = []

for cls in EMOTIONS:
    for img_name in os.listdir(os.path.join(TRAIN_DIR, cls)):
        img_path = os.path.join(TRAIN_DIR, cls, img_name)
        with open(img_path, 'rb') as f:
            hash_val = hashlib.md5(f.read()).hexdigest()
            if hash_val in hashes:
                duplicates.append(img_path)
            else:
                hashes.add(hash_val)

print("Duplicate images found:", len(duplicates))
# Out:
# Duplicate images found: 145

# %%
import shutil

save_path = os.path.join(TRAIN_DIR, "duplicates_found")
os.makedirs(save_path, exist_ok=True)

for dup in duplicates:
    try:
        shutil.move(dup, os.path.join(save_path, os.path.basename(dup)))
        print(f"Moved: {dup}")
    except Exception as e:
        print(f"Failed to move {dup}: {e}")
# Out:
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\angry\Training_267631.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\angry\Training_3125398.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\angry\Training_31835561.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\angry\Training_44516923.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\angry\Training_80018116.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\angry\Training_91034450.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\angry\Training_96214713.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_22935237.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_29984761.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_35175107.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_37121508.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_3858356.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_41636253.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_41823318.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_45352156.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_46906248.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_50925427.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_5151632.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_52049977.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_52126443.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_5420780.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_54737771.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_57692374.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_59432375.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_61342142.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_61515877.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_62600200.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_62886279.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_62976704.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_63881263.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_66197221.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_67037685.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_67085421.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_680349.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_71679475.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_73744534.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_7383909.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_73889032.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_74911774.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_75391172.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_7602986.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_77723520.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_80443921.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_81867140.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_82179195.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_82298698.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_84874359.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_8536264.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_85690881.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_87371135.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_8819454.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_89094363.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_8937293.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_91698666.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_92118201.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_92886088.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_9567515.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_96016286.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_96356478.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_96642479.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_96859053.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\disgust\Training_97638867.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\fear\Training_39001074.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\fear\Training_57026322.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\fear\Training_64099735.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\fear\Training_67564066.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\fear\Training_69754609.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\fear\Training_70042615.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\fear\Training_71741660.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\fear\Training_78495484.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\fear\Training_8026828.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\fear\Training_89050041.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\fear\Training_98368424.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\fear\Training_99452623.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\happy\Training_44398410.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\happy\Training_61219060.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\happy\Training_78558031.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\sad\Training_4071905.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\sad\Training_48621797.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\sad\Training_54602400.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\sad\Training_64310531.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\sad\Training_70378996.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\sad\Training_88381807.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_29627165.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_32225696.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_3240036.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_35060392.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_41850025.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_43204737.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_45096582.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_45102794.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_47418678.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_49350956.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_4935733.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_50815216.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_51008998.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_51748108.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_53006838.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_53647427.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_5393442.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_55838680.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_5596506.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_56689133.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_59285565.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_60058102.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_62822207.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_66306097.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_67971518.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_69225397.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_70775056.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_71436627.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_76105973.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_76860074.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_77853139.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_77967966.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_7906576.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_79118199.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_80557580.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_80565344.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_80790277.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_81294812.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_8163666.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_82657965.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_82810364.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_86125282.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_88570558.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_9003378.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_9013322.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_90347319.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_90519473.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_90780069.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_91045206.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_92044858.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_92312755.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_9243945.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_9428441.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_94815054.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_96765324.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_98067546.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_98539906.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\surprise\Training_9932811.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\neutral\Training_39534614.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\neutral\Training_47056432.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\neutral\Training_60830256.jpg
# Moved: C:\Users\ASUS\Desktop\Digital\Emoji-Detection-System\FER-2013_sampled\FER-2013_sampled\train_balanced_7000\neutral\Training_89335926.jpg

# %%
import hashlib

def check_and_move_bad_images(directory, label):
    seen = set()
    duplicates = []
    corrupt_images = []

    save_dup_path = os.path.join(directory, f"{label}_duplicates_found")
    save_corrupt_path = os.path.join(directory, f"{label}_corrupt_found")
    os.makedirs(save_dup_path, exist_ok=True)
    os.makedirs(save_corrupt_path, exist_ok=True)

    for emotion in EMOTIONS:
        emo_path = os.path.join(directory, emotion)
        for img_name in os.listdir(emo_path):
            img_path = os.path.join(emo_path, img_name)
            try:
                img = Image.open(img_path)
                img.verify()

                # re-open for hashing
                img = Image.open(img_path)
                img_hash = hash(img.tobytes())

                if img_hash in seen:
                    duplicates.append(img_path)
                    target_folder = os.path.join(save_dup_path, emotion)
                    os.makedirs(target_folder, exist_ok=True)
                    shutil.move(img_path, os.path.join(target_folder, img_name))
                else:
                    seen.add(img_hash)

            except Exception:
                corrupt_images.append(img_path)
                target_folder = os.path.join(save_corrupt_path, emotion)
                os.makedirs(target_folder, exist_ok=True)
                try:
                    shutil.move(img_path, os.path.join(target_folder, img_name))
                except Exception as e:
                    print(f"Failed to move corrupt file: {img_path} — {e}")

    return duplicates, corrupt_images 
train_dups, train_corrupts = check_and_move_bad_images(TRAIN_DIR, "train")
print(f"Training - Duplicates moved: {len(train_dups)}, Corrupt images moved: {len(train_corrupts)}")
# Out:
# Training - Duplicates moved: 0, Corrupt images moved: 0

# %%
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler
import pandas as pd
import seaborn as sns

# Flatten images for PCA/t-SNE
samples, labels = [], []
for cls in EMOTIONS:
    for img_name in os.listdir(os.path.join(TRAIN_DIR, cls))[:30]:
        img = Image.open(os.path.join(TRAIN_DIR, cls, img_name)).convert("L").resize((48, 48))
        samples.append(np.array(img).flatten())
        labels.append(cls)

scaled = StandardScaler().fit_transform(samples)
pca = PCA(n_components=2).fit_transform(scaled)

df_pca = pd.DataFrame(pca, columns=["PCA1", "PCA2"])
df_pca["class"] = labels

sns.scatterplot(data=df_pca, x="PCA1", y="PCA2", hue="class")
plt.title("PCA Projection of Image Space")
plt.show()
